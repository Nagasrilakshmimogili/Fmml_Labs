# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagasrilakshmimogili/Fmml_Labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 11:15:10--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   364MB/s    in 0.2s
#
# 2024-03-31 11:15:10 (364 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10448   1104.2930v3  With inspiration from Random Forests (RF) in t...  stat
# 26392  1610.03023v2  Learning powerful feature representations for ...    cs
# 7865    1204.0885v1  Time delays are components that make time-lag ...    cs
# 26296  1609.07370v1  Image and texture synthesis is a challenging t...    cs
# 21689   1308.5609v2  Canonical correlation analysis (CCA) has been ...  stat
# ...             ...                                                ...   ...
# 11361  1511.02386v2  Black box variational inference allows researc...  stat
# 5334    1301.5650v2  Neural language models (LMs) based on recurren...  stat
# 24809   1412.0265v2  In this paper, we develop an approach to explo...    cs
# 7774   1803.02922v2  Modern supervised learning techniques, particu...  stat
# 34082   1212.2006v2  Both supervised learning methods and LDA based...    cs
#
#                                                    title  year  \
# 10448                                    Cluster Forests  2011
# 26392  Learning Low Dimensional Convolutional Neural ...  2016
# 7865   PID Parameters Optimization by Using Genetic A...  2012
# 26296  Example-Based Image Synthesis via Randomized P...  2016
# 21689  Frequency Recognition in SSVEP-based BCI using...  2013
# ...                                                  ...   ...
# 11361                    Hierarchical Variational Models  2015
# 5334   Regularization and nonlinearities for neural l...  2013
# 24809  Kernel Methods on Riemannian Manifolds with Ga...  2014
# 7774   Fast Convergence for Stochastic and Distribute...  2018
# 34082  A Novel Feature-based Bayesian Model for Query...  2012
#
#                                                 keywords
# 10448  [inspiration, classification, clustering, geom...
# 26392  [representations, retrieval, challenging, trad...
# 7865   [components, biological, measurement, computat...
# 26296  [synthesis, challenging, attention, processing...
# 21689  [canonical, correlation, frequency, recognitio...
# ...                                                  ...
# 11361  [variational, inference, researchers, prototyp...
# 5334   [recurrent, successful, character, particular,...
# 24809  [exploiting, naturally, represented, riemannia...
# 7774   [supervised, techniques, particularly, dimensi...
# 34082  [supervised, successfully, summarization, supe...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10448    [inspiration, classification, clustering, geom...
# 26392    [representations, retrieval, challenging, trad...
# 7865     [components, biological, measurement, computat...
# 26296    [synthesis, challenging, attention, processing...
# 21689    [canonical, correlation, frequency, recognitio...
#                                ...
# 28434    [prevalent, generally, aesthetic, increasingly...
# 20448    [navigation, benchmark, evaluating, abilities,...
# 14444    [attention, comparison, efficiency, statistica...
# 8789     [collaborative, researchers, discovering, know...
# 4664     [repetitivefrequent, discovery, practitioners,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8835 words.
# Out of those 4575 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6ed138d3-b04c-47de-9a7d-a6000cd4e3e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ed138d3-b04c-47de-9a7d-a6000cd4e3e8")) {                    Plotly.newPlot(                        "6ed138d3-b04c-47de-9a7d-a6000cd4e3e8",                        [{"x":["resistant","expression","geometrically","inspiration","assignments","competitors","different","aggregates","resembles","favorably","desirable","theoretical","clusterings","dimensional","clustering","progressively","perturbation","classification","performance","empirical","consuming","extracting","particular","complexity","conventional","convolution","respectively","evaluated","investigate","unsatisfactory","connected","representations","convolutional","extracted","retrieval","effective","resolution","perceptron","challenging","traditional","architecture","parameters","measurement","optimization","components","algorithm","controller","determining","computation","implement","compensate","biological","iterative","processing","likelihood","modelling","generation","pyramidal","synthesized","consisting","statistical","contributions","randomized","intuitive","framework","suggesting","synthesis","estimated","generating","attention","contribution","parametric","evaluation","handwritten","addresses","interfaces","constructed","reference","candidate","combination","constrained","competing","especially","recognition","frequency","superiority","optimized","transforms","comparison","promising","indicates","completely","demonstrates","canonical","correlation","potential","efficiency","experimental","filtering","associated","annotations","handwriting","information","collected","exclusively","recognize","characters","objective","character","subsequently","identified","identification","successfully","ultrametric","previously","organization","semantically","possibilities","distinguish","meaningful","hierarchy","penalized","classifiers","hierarchical","minimizes","redundancy","laplacian","relevance","effectiveness","appropriate","principal","maximizes","literature","benchmark","estimation","unsupervised","confidence","demonstrate","component","selection","technology","integration","inference","proposals","specification","solutions","described","processes","techniques","limitations","integrated","perceptual","generative","adversarial","simulation","conditional","differentiable","conditioning","discriminator","constrain","workflows","unconditional","reservoir","stochastic","conditioned","leverages","geostatistical","technique","properties","successful","represent","simulations","variation","environment","accommodation","probability","including","evolution","independently","introduced","variations","throughout","conditions","partially","evolutionary","experienced","explained","evaluating","demonstrated","environments","robustness","environmental","generations","increases","bottlenecks","communication","introduce","noiseless","reminiscent","simultaneously"],"y":[5,40,6,6,12,8,722,8,4,30,31,169,1,179,140,9,11,483,846,159,34,45,291,232,108,40,87,159,140,2,73,221,345,104,118,259,137,20,259,172,236,236,30,317,89,827,18,35,140,68,6,41,76,287,64,43,132,2,13,43,144,46,27,38,548,14,38,54,103,156,70,38,265,23,44,15,54,55,53,130,52,27,118,346,54,38,51,19,124,119,22,33,58,28,58,140,154,385,63,117,59,6,684,79,8,53,31,161,60,19,52,108,82,1,89,19,31,15,44,55,37,10,115,92,16,14,11,44,178,78,33,9,125,178,208,130,51,541,89,168,61,41,220,32,20,163,71,104,388,76,67,31,135,123,76,92,22,10,23,11,2,3,3,127,18,37,0,224,218,78,92,39,54,123,1,176,230,65,39,127,65,18,122,56,72,12,13,46,90,98,94,13,8,49,9,57,361,4,1,105],"type":"bar"},{"x":["resistant","expression","geometrically","inspiration","assignments","competi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4575,), (4575, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8058333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Using</span> <span style=''>Barriers</span> <span style=''>to</span> <span style=''>Reduce</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sensitivity</span> <span style=''>to</span> <span style=''>Edge</span> <span style=''>Miscalculations</span> <span style=''>of</span> <span style=''>Casting</span> <span style=''>Based</span> <span style=''>Object</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Projection</span> <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>3D</span> <span style=''>motion</span> <span style=''>tracking</span> <span style=''>is</span> <span style=''>a</span> <span style=''>critical</span> <span style=''>task</span> <span style=''>in</span> <span style=''>many</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style=''>markerless</span> <span style=''>3D</span> <span style=''>motion</span> <span style=''>tracking</span> <span style=''>systems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determine</span> <span style=''>the</span> <span style=''>most</span> <span style=''>relevant</span> <span style=''>object</span> <span style=''>in</span> <span style=''>the</span> <span style=''>screen</span> <span style=''>and</span> <span style=''>then</span> <span style=''>track</span> <span style=''>it</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>continuously</span> <span style='background-color:rgba(255, 0, 0, 0.3096446700507614);'>estimating</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>features</span> <span style=''>(center</span> <span style=''>and</span> <span style=''>area)</span> <span style=''>from</span> <span style=''>the</span> <span style=''>edge</span> <span style=''>image</span> <span style=''>and</span> <span style=''>a</span> <span style=''>point</span> <span style=''>inside</span> <span style=''>the</span> <span style=''>relevant</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>(namely</span> <span style=''>inner</span> <span style=''>point)</span> <span style=''>until</span> <span style=''>the</span> <span style=''>tracking</span> <span style=''>fails</span> <span style=''>Existing</span> <span style=''>reliable</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>ray</span> <span style=''>casting</span> <span style=''>or</span> <span style=''>grid</span> <span style=''>filling</span> <span style=''>from</span> <span style=''>the</span> <span style=''>inner</span> <span style=''>point</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>assume</span> <span style=''>the</span> <span style=''>edge</span> <span style=''>image</span> <span style=''>to</span> <span style=''>be</span> <span style=''>accurate</span> <span style=''>However</span> <span style=''>in</span> <span style=''>real</span> <span style=''>case</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scenarios</span> <span style=''>edge</span> <span style=''>miscalculations</span> <span style=''>may</span> <span style=''>arise</span> <span style=''>from</span> <span style=''>low</span> <span style=''>contrast</span> <span style=''>between</span> <span style=''>the</span> <span style=''>target</span> <span style=''>object</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Smoothing</span> <span style=''>proximal</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>for</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>sparsity</span> <span style=''>inducing</span> <span style=''>penalty</span> <span style=''>that</span> <span style=''>encodes</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>on</span> <span style=''>either</span> <span style=''>the</span> <span style=''>input</span> <span style=''>or</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>two</span> <span style=''>widely</span> <span style=''>adopted</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalties</span> <span style=''>of</span> <span style=''>this</span> <span style=''>kind</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivating</span> <span style=''>examples</span> <span style=''>(1)</span> <span style=''>the</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overlapping</span> <span style=''>group</span> <span style=''>lasso</span> <span style=''>penalty</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>from</span> <span style=''>the</span> <span style=''>group</span> <span style=''>lasso</span> <span style=''>penalty</span> <span style=''>and</span> <span style=''>(2)</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>guided</span> <span style=''>fused</span> <span style=''>lasso</span> <span style=''>penalty</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>from</span> <span style=''>the</span> <span style=''>fused</span> <span style=''>lasso</span> <span style=''>penalty</span> <span style=''>For</span> <span style=''>both</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalties</span> <span style=''>due</span> <span style=''>to</span> <span style=''>their</span> <span style=''>nonseparability</span> <span style=''>and</span> <span style=''>nonsmoothness</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developing</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>method</span> <span style=''>remains</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>approach</span> <span style=''>the</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Online</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sparsification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dictionary</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>from</span> <span style=''>online</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sparsification</span> <span style=''>using</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>formula</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>expresses</span> <span style=''>the</span> <span style=''>expected</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>determinant</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>Gram</span> <span style=''>matrix</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>eigenvalues</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6528925619834711);'>covariance</span> <span style=''>operator</span> <span style=''>Using</span> <span style=''>this</span> <span style=''>formula</span> <span style=''>we</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>connect</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cardinality</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>with</span> <span style=''>the</span> <span style=''>eigen</span> <span style=''>decay</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6528925619834711);'>covariance</span> <span style=''>operator</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.35384615384615375);'>technical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>will</span> <span style=''>always</span> <span style=''>grow</span> <span style=''>sub</span> <span style=''>linearly</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>and</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3846153846153845);'>consequence</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>regressor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stratified</span> <span style=''>Sampling</span> <span style=''>for</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Differentiable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stratified</span> <span style=''>sampling</span> <span style=''>for</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiable</span> <span style=''>function</span> <span style=''>given</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>to</span> <span style=''>the</span> <span style=''>function</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>a</span> <span style=''>sampling</span> <span style=''>scheme</span> <span style=''>that</span> <span style=''>samples</span> <span style=''>more</span> <span style=''>often</span> <span style=''>in</span> <span style=''>regions</span> <span style=''>where</span> <span style=''>the</span> <span style=''>function</span> <span style=''>oscillates</span> <span style=''>more</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>allocating</span> <span style=''>the</span> <span style=''>samples</span> <span style=''>such</span> <span style=''>that</span> <span style=''>they</span> <span style=''>are</span> <span style=''>well</span> <span style=''>spread</span> <span style=''>on</span> <span style=''>the</span> <span style=''>domain</span> <span style=''>(this</span> <span style=''>notion</span> <span style=''>shares</span> <span style=''>similitude</span> <span style=''>with</span> <span style=''>low</span> <span style=''>discrepancy)</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>estimate</span> <span style=''>returned</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>almost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarly</span> <span style=''>accurate</span> <span style=''>as</span> <span style=''>the</span> <span style=''>estimate</span> <span style=''>that</span> <span style=''>an</span> <span style=''>optimal</span> <span style=''>oracle</span> <span style=''>strategy</span> <span style=''>(that</span> <span style=''>would</span> <span style=''>know</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>function</span> <span style=''>everywhere)</span> <span style=''>would</span> <span style=''>return</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>sample</span> <span style=''>analysis</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09546109510086455)
# 	segmentation (0.0670028818443804)
# 	architecture (0.08501440922190202)
# 	processing (0.10338616714697406)
# 	experimental (0.13868876080691642)
# 	information (0.24639769452449567)
# 	different (0.2600864553314121)
# 	detection (0.1340057636887608)
# 	recognition (0.12463976945244956)
# 	convolutional (0.12427953890489914)
#
# Some Statistics words are:
# 	estimation (0.16403162055335968)
# 	stochastic (0.13488142292490118)
# 	distribution (0.17885375494071146)
# 	algorithm (0.39278656126482214)
# 	theoretical (0.15711462450592886)
# 	variables (0.14525691699604742)
# 	statistical (0.15760869565217392)
# 	dimensional (0.18379446640316205)
# 	inference (0.20503952569169961)
# 	regression (0.18280632411067194)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d7386d6f-77a3-41cb-8239-b90f926b36ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7386d6f-77a3-41cb-8239-b90f926b36ec")) {                    Plotly.newPlot(                        "d7386d6f-77a3-41cb-8239-b90f926b36ec",                        [{"x":["resistant","expression","geometrically","inspiration","assignments","competitors","different","aggregates","resembles","favorably","desirable","theoretical","clusterings","dimensional","clustering","progressively","perturbation","classification","performance","empirical","consuming","extracting","particular","complexity","conventional","convolution","respectively","evaluated","investigate","unsatisfactory","connected","representations","convolutional","extracted","retrieval","effective","resolution","perceptron","challenging","traditional","architecture","parameters","measurement","optimization","components","algorithm","controller","determining","computation","implement","compensate","biological","iterative","processing","likelihood","modelling","generation","pyramidal","synthesized","consisting","statistical","contributions","randomized","intuitive","framework","suggesting","synthesis","estimated","generating","attention","contribution","parametric","evaluation","handwritten","addresses","interfaces","constructed","reference","candidate","combination","constrained","competing","especially","recognition","frequency","superiority","optimized","transforms","comparison","promising","indicates","completely","demonstrates","canonical","correlation","potential","efficiency","experimental","filtering","associated","annotations","handwriting","information","collected","exclusively","recognize","characters","objective","character","subsequently","identified","identification","successfully","ultrametric","previously","organization","semantically","possibilities","distinguish","meaningful","hierarchy","penalized","classifiers","hierarchical","minimizes","redundancy","laplacian","relevance","effectiveness","appropriate","principal","maximizes","literature","benchmark","estimation","unsupervised","confidence","demonstrate","component","selection","technology","integration","inference","proposals","specification","solutions","described","processes","techniques","limitations","integrated","perceptual","generative","adversarial","simulation","conditional","differentiable","conditioning","discriminator","constrain","workflows","unconditional","reservoir","stochastic","conditioned","leverages","geostatistical","technique","properties","successful","represent","simulations","variation","environment","accommodation","probability","including","evolution","independently","introduced","variations","throughout","conditions","partially","evolutionary","experienced","explained","evaluating","demonstrated","environments","robustness","environmental","generations","increases","bottlenecks","communication","introduce","noiseless","reminiscent","simultaneously","important","approximation","protocols","communicate","minimizing","exponential","classifier","distributed","practitioner","optimistic","parameter","operational","generalization","depending","reasonable","uncertainty","algorithms","knowledge","propagates","predictive","perspective","pessimistic","regularization","practitioners","hypothesis","understand","statistically","incorporate","identifying","geometric","specifically","principle","anomalous","significance","anomalies","alternatives","minimization","classifying","irrespective","detecting","detection","discrimination","interested","instances","simulated","challenge","prediction","inception","predictions","involving","designing","sensitivity","conference","regression","extractor","impro ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	geostatistical
# 	practitioner
# 	practicing
# 	heartbeats
# 	particulars
# 	nonconjugate
# 	couplings
# 	rescaling
# 	trilinear
# 	blockmodel
# 	seasonality
# 	epanechnikov
# 	inverting
# 	representer
# 	eigendecomposition
# 	mitigating
# 	literally
# 	timeseries
# 	thresholded
# 	nonparametrics
# Some words which never appear in Statistics papers:
# 	semantically
# 	generations
# 	withdrawn
# 	transaction
# 	hypercolumns
# 	dissipation
# 	neuromorphic
# 	executing
# 	purposefully
# 	consistencies
# 	countermeasures
# 	ontologies
# 	deductive
# 	incompleteness
# 	perceptually
# 	susceptibility
# 	incidental
# 	angiography
# 	agriculture
# 	photometric

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0926240915416734e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
